# %%
#Sorting - operation of arranging numbers in an order (usually ascending)

L = [2, 5, 3, 1, 4]

# Expected output - [1, 2, 3, 4, 5]

# in-built sort function sorts a given list
L.sort()

print(L)

# Why should we study other sorting techniques?
# - Develops algorithmic thinking and analysis.
# Out:
# [1, 2, 3, 4, 5]

# %%
# Bubble sort

L = [5,1,2,3,6]

# Get the length of the list
n = len(L)

# Outer loop to keep track of passes
for i in range(1,n): # values i = 1, ... , n-1
# Alternatively the below for loop also works
# (Make sure you use the corresponding 2nd j loop too)
# for i in range(n-1) # values i = 0, ..., n-2

# Variable to count the number of comparisons
  count = 0
# Inner loop to perform pairwise comparisons
  for j in range(n-i): #values j = 0, 1, ..., n-i-1
# Alternatively the below for loop also works
# for j in range(n-i-1) #values j = 0, 1, ..., n-i-2
    # Compare the pairs of elements
    if L[j] > L[j+1]:
      # Swap
      L[j] , L[j+1] = L[j+1], L[j]
    count += 1
# Print the number of comparisons per pass
  print("Pass:",i)
  print("No. of comparisons:",count)

print("After Bubble sort:")
print(L)
# Out:
# Pass: 1
# No. of comparisons: 4
# Pass: 2
# No. of comparisons: 3
# Pass: 3
# No. of comparisons: 2
# Pass: 4
# No. of comparisons: 1
# After Bubble sort:
# [1, 2, 3, 5, 6]

# %%
# Swapping
a = 3
b = 5

a, b = b, a

print(a,b)
# Out:
# 5 3

# %%
# Selection sort

L = [2, 5, 3, 1, 4]

# Get the length of the list
n = len(L)

# Outer loop to indicate number of passes
for i in range(n-1): # i = 0, 1, ..., n-2
# pos - variable to hold the current position, at which the smallest value to be inserted
# min - variable to hold the index of the smallest element
  pos = i
  min = i

# Inner loop to go through further indices and select the smallest value
  for j in range(i+1,n): # j = i+1, i+2, ..., n-1
# If any index j is founf such that it has a smaller element than min, update min
    if L[j] < L[min]:
      min = j
  #swap L[min] and L[pos]
  L[min] , L[pos] = L[pos], L[min]

print("Result of selection sort:")
print(L)
# Out:
# Result of selection sort:
# [1, 2, 3, 4, 5]

# %%
# Insertion sort

L = [2, 5, 3, 1, 4]

# Get the length of the list
n = len(L)

# Outer loop to run through all indices for inserting new elements
for i in range(1,n):
# key is the current element to be inserted
  key = L[i]
  j = i-1

# Compare the new element with all the lower indices and
# shift the old element at index j by 1 position to make room for new element
# repeat until: either j goes negative or new element is greater than element at j
  while j>=0 and key < L[j]:
    L[j+1] = L[j]
    j = j-1

# Insert the new element at it's suitable position - j+1
  L[j+1] = key

print("Result of insertion sort:")
print(L)
# Out:
# Result of insertion sort:
# [1, 2, 3, 4, 5]

# %%
# Quick sort

def quick_sort(L):

# If there is a single element, return it
  if len(L) <= 1:
    return L
  else:
# Choose the mid element of the list as the pivot
    pivot = L[len(L)//2]
# Create groups of less, equal and greater with the pivot
    less = [x for x in L if x < pivot]
    equal = [x for x in L if x == pivot]
    greater = [x for x in L if x > pivot]

# return less + equal + greater as the final list
  return quick_sort(less)+equal+quick_sort(greater)

L = [2, 5, 3, 1, 4]
L = quick_sort(L)

print("Result of quick sort:")
print(L)
# Out:
# Result of quick sort:
# [1, 2, 3, 4, 5]

# %%
import pandas as pd

df = pd.read_csv('Height-Weight.csv')

df.head()
# Out:
#    Height  Weight
# 0     159      62
# 1     195      97
# 2     167      72
# 3     179      83
# 4     165      68

# %%
X = df['Weight']

# %%
actual = df['Height']

# %%
print(X)
# Out:
# 0     62
# 1     97
# 2     72
# 3     83
# 4     68
#       ..
# 94    94
# 95    73
# 96    52
# 97    62
# 98    64
# Name: Weight, Length: 99, dtype: int64

# %%
import numpy as np

coeff = np.linspace(0,5,50)

error = []

for m in coeff:
  pred = X*m
  error.append(np.mean(abs(actual - pred)))

# %%
print(error)
# Out:
# [171.03030303030303, 163.50195835910122, 155.97361368789942, 148.4452690166976, 140.91692434549577, 133.38857967429396, 125.86023500309213, 118.33189033189034, 110.80354566068853, 103.27520098948673, 95.74685631828488, 88.21851164708305, 80.69016697588125, 73.16182230467946, 65.63347763347763, 58.10513296227581, 50.57678829107401, 43.048443619872195, 35.52009894867037, 27.99175427746855, 20.540094825809103, 14.063492063492065, 10.06472892187177, 10.056070913213777, 13.359307359307362, 18.630797773654912, 25.351886209029058, 32.507111935683376, 39.82106782106783, 47.29169243454957, 54.82003710575142, 62.348381776953225, 69.87672644815503, 77.40507111935685, 84.93341579055864, 92.46176046176046, 99.99010513296228, 107.51844980416409, 115.04679447536594, 122.57513914656775, 130.10348381776956, 137.63182848897137, 145.16017316017317, 152.68851783137495, 160.21686250257682, 167.74520717377862, 175.2735518449805, 182.80189651618227, 190.33024118738408, 197.85858585858585]

# %%
# plot the values of error againt the co_eff

import matplotlib.pyplot as plt

plt.scatter(coeff, error)
plt.xlabel('co_eff')
plt.ylabel('error')
plt.show()
